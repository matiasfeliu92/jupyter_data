# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
df_you_tube = pd.read_csv('./CSV/you_tube.csv', encoding='iso-8859-1')
df_you_tube
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
df_you_tube.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df_you_tube.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df_you_tube.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df_you_tube.dtypes
# Out:
# rank                                         int64
# Youtuber                                    object
# subscribers                                  int64
# video views                                float64
# category                                    object
# Title                                       object
# uploads                                      int64
# Country                                     object
# Abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# ...

# %%
df_cleaned = df_you_tube.replace('nan', pd.NA)

numeric_columns = ['rank', 'subscribers', 'video views', 'video_views_for_the_last_30_days',
                   'lowest_monthly_earnings', 'highest_monthly_earnings', 'lowest_yearly_earnings',
                   'highest_yearly_earnings', 'subscribers_for_last_30_days', 'created_year', 'Unemployment rate']

for column in numeric_columns:
    df_cleaned[column] = pd.to_numeric(df_cleaned[column], errors='coerce')
    
df_cleaned = df_cleaned.dropna()

top_10_subscribers = df_cleaned.nlargest(10, 'subscribers')
top_10_subscribers
# Out:
#     rank                    Youtuber  subscribers   video views  \
# 0      1                    T-Series    245000000  2.280000e+11
# 2      3                     MrBeast    166000000  2.836884e+10
# 3      4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4      5                   SET India    159000000  1.480000e+11
# 8      9                 Like Nastya    106000000  9.047906e+10
# 9     10               Vlad and Niki     98900000  7.718017e+10
# 10    11           Zee Music Company     96700000  5.785629e+10
# 11    12                         WWE     96000000  7.742847e+10
# 13    14                   BLACKPINK     89800000  3.214460e+10
# 15    16                    Sony SAB     83000000  1.010000e+11
#
#           category                       Title  uploads        Country  \
# 0            Music                    T-Series    20082          India
# 2    Entertainment                     MrBeast      741  United States
# ...

# %%
df_cleaned
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# 8       9                 Like Nastya    106000000  9.047906e+10
# ..    ...                         ...          ...           ...
# 989   990                   Migos ATL     12400000  6.993406e+09
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# ...

# %%
# Figure Size
fig, ax = plt.subplots(figsize=(12, 8))

# Horizontal Bar Plot
ax.barh(top_10_subscribers['Youtuber'], top_10_subscribers['subscribers'])

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad=5)
ax.yaxis.set_tick_params(pad=10)

# Add x, y gridlines
ax.grid(visible=True, which='both', axis='y', color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width() + 0.2, i.get_y() + i.get_height()/2,
             f"{i.get_width():.2f}",
             fontsize=10, color='black', va='center', ha='left')

# Add Plot Title
ax.set_title('Top 10 YouTube Channels by Subscribers', loc='left')

# Show Plot
plt.tight_layout()
plt.show()

# %%
# Ajustar el tamaño de la figura
fig = plt.figure(figsize=(10, 6))  # Ancho: 10 pulgadas, Alto: 6 pulgadas
ax = fig.add_subplot(111, projection='3d')

# Datos de ejemplo (reemplaza estos con tus datos reales)
x = df_cleaned['subscribers']
y = df_cleaned['video views']
z = df_cleaned['uploads']
c = df_cleaned['video_views_for_the_last_30_days']

# Escala de colores utilizando Seaborn (opcional)
cmap = sns.color_palette("viridis", as_cmap=True)

# Crear el gráfico de dispersión 3D
scatter = ax.scatter(x, y, z, c=c, s=40, cmap=cmap, alpha=0.7)

# Agregar la barra de colores
cbar = plt.colorbar(scatter)
cbar.set_label('Video Views for the Last 30 Days')

# Configurar etiquetas de ejes y título
ax.set_xlabel('Subscribers')
ax.set_ylabel('Video Views')
ax.set_zlabel('Uploads')
ax.set_title('YouTube Channels: Subscribers, Video Views, and Uploads')

plt.show()

# %%
channel_types = df_cleaned['channel_type'].unique()
channel_counts = df_cleaned['channel_type'].value_counts()

plt.figure(figsize=(10, 6))
colors = plt.cm.Set3.colors
plt.bar(channel_types, channel_counts, color=colors)
plt.title('Distribution of YouTube Channel Types')
plt.xlabel('Channel Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
channel_counts = df_cleaned['channel_type'].value_counts()
labels = channel_counts.index
sizes = channel_counts.values

plt.figure(figsize=(15, 15))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=plt.cm.Set3.colors, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of YouTube Channel Types')
plt.show()

# %%
category_colors = {
    'Music': 'blue',
    'Entertainment': 'green',
    'Education': 'orange',
    # Agrega más categorías y colores aquí
}

colors = [category_colors.get(category, 'gray') for category in df_cleaned['category']]

plt.figure(figsize=(10, 6))
plt.scatter(df_cleaned['subscribers'], df_cleaned['video views'], s=df_cleaned['video_views_for_the_last_30_days'],
            c=colors, alpha=0.7)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Subscribers (in billions)')
plt.ylabel('Video Views (in billions)')
plt.title('Subscribers vs. Video Views by Category')
plt.grid(True)
plt.show()
