# %% [markdown]
# ### PAUTAS PARA EL ANALISIS DE LA DATA
# * verificar la distribucion de barrios populares en la provincia de Buenos Aires

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns

# %%
df_barrios_populares = pd.read_csv('./CSV/barrios_populares_final.csv')
df_barrios_populares.head()
# Out:
#    Unnamed: 0 nombre_barrio     provincia departamento            localidad  \
# 0           0   Monterrey I  Buenos Aires        Pilar    Presidente Derqui
# 1           1   Malvinas II  Buenos Aires     La Plata  José Melchor Romero
# 2           2   Ferroviario  Buenos Aires     La Plata     Angel Etcheverry
# 3           3   La Favelita  Buenos Aires     La Plata               Tolosa
# 4           4        Casaca  Buenos Aires     La Plata            City Bell
#
#    cantidad_viviendas_aproximadas  cantidad_familias_aproximada  \
# 0                              40                            44
# 1                             290                           319
# 2                             133                           146
# 3                             122                           134
# 4                              20                            22
#
#                            energia_electrica  \
# 0  Conexión a la red con medidor comunitario
# ...

# %%
df_barrios_populares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1933 entries, 0 to 1932
# Data columns (total 39 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Unnamed: 0                                       1933 non-null   int64
#  1   nombre_barrio                                    1933 non-null   object
#  2   provincia                                        1933 non-null   object
#  3   departamento                                     1933 non-null   object
#  4   localidad                                        1933 non-null   object
#  5   cantidad_viviendas_aproximadas                   1933 non-null   int64
#  6   cantidad_familias_aproximada                     1933 non-null   int64
#  7   energia_electrica                                1933 non-null   object
#  8   efluentes_cloacales                              1933 non-null   object
# ...

# %%
df_barrios_populares.describe()
# Out:
#         Unnamed: 0  cantidad_viviendas_aproximadas  \
# count  1933.000000                     1933.000000
# mean   1626.082256                      269.865494
# std    1634.906926                      478.682514
# min       0.000000                        8.000000
# 25%     483.000000                       43.000000
# 50%     966.000000                      110.000000
# 75%    2629.000000                      300.000000
# max    5322.000000                     7850.000000
#
#        cantidad_familias_aproximada  superficie_m2  personas_genero_masc  \
# count                   1933.000000   1.933000e+03           1933.000000
# mean                     296.912571   1.211583e+05            273.488360
# std                      526.533187   2.058133e+05            502.537498
# min                        9.000000   3.700000e+02              0.000000
# 25%                       47.000000   1.568700e+04             34.000000
# ...

# %%
df_barrios_populares.isnull().sum()
# Out:
# Unnamed: 0                                         0
# nombre_barrio                                      0
# provincia                                          0
# departamento                                       0
# localidad                                          0
# cantidad_viviendas_aproximadas                     0
# cantidad_familias_aproximada                       0
# energia_electrica                                  0
# efluentes_cloacales                                0
# agua_corriente                                     0
# cocina                                             0
# calefaccion                                        0
# situacion_dominial                                 0
# clasificacion_barrio                               0
# superficie_m2                                      0
# personas_genero_masc                               0
# personas_genero_fem                                0
# personas_genero_otrx                               0
# ...

# %%
# df_10_barrios_mas_poblados = df_barrios_populares[df_barrios_populares['provincia'] == 'Buenos Aires'].nlargest(8, 'cantidad_familias_aproximada')[['personas_genero_masc', 'personas_genero_fem',
#        'personas_genero_otrx',
#        'no_sabe_si_recibe_asignacion_universal_por_hijo',
#        'tipo_propiedad_de_quienes_vieven_en_ella', 'tipo_propiedad_alquilada',
#        'tipo_propiedad_prestada', 'rango_edad_0_a_4_anios',
#        'rango_edad_5_a_9_anios', 'rango_edad_10_a_14_anios',
#        'rango_edad_15_a_19_anios', 'rango_edad_20_a_24_anios',
#        'rango_edad_25_a_29_anios', 'rango_edad_30_a_34_anios',
#        'rango_edad_35_a_39_anios', 'rango_edad_40_a_44_anios',
#        'rango_edad_45_a_49_anios', 'rango_edad_50_a_54_anios',
#        'rango_edad_55_a_59_anios', 'rango_edad_60_a_64_anios',
#        'rango_edad_65_a_69_anios', 'rango_edad_70_a_74_anios',
#        'rango_edad_75_a_79_anios', 'rango_edad_80_o_mas_anios']]
# # print(df_10_barrios_mas_poblados.columns)
# df_10_barrios_mas_poblados

df_barrios_populares['cantidad_familias_aproximada'].describe()
# Out:
# count    1933.000000
# mean      296.912571
# std       526.533187
# min         9.000000
# 25%        47.000000
# 50%       121.000000
# 75%       330.000000
# max      8635.000000
# Name: cantidad_familias_aproximada, dtype: float64

# %%
sns.distplot(df_barrios_populares['cantidad_familias_aproximada'])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_15416\3710026820.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_barrios_populares['cantidad_familias_aproximada'])
# <Axes: xlabel='cantidad_familias_aproximada', ylabel='Density'>

# %%
print({'skew': df_barrios_populares['cantidad_familias_aproximada'].skew()})
print({'kurt': df_barrios_populares['cantidad_familias_aproximada'].kurt()})
# Out:
# {'skew': 5.922473792261084}
# {'kurt': 57.51980152690019}
