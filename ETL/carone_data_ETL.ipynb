# %%
import pandas as pd
from datetime import datetime, timedelta
import requests
from io import StringIO
from bs4 import BeautifulSoup
from lxml import html

# %%
base_url = "https://www.carone.com.ar"

# %% [markdown]
# ## ETL de los links de usados y 0km

# %% [markdown]
# ### usando https://www.carone.com.ar/categoria-producto/0km/ para obtener la lista de autos 0km

# %%
okm_model_links = []

i = 0
while True:
    res = requests.get(f"{base_url}/categoria-producto/0km/page/{i+1}/")
    print(f"{base_url}/categoria-producto/0km/page/{i+1}/")
    if res.status_code != 200:
        break

    soup = BeautifulSoup(res.text, "html.parser")
    tree = html.fromstring(res.content)
    div_col_12_elements = tree.xpath('//div[contains(@class, "col-12")]')
    okm_page_links = [div.xpath('.//a/@href') for div in div_col_12_elements]
    okm_linkss = set([link[0] for link in okm_page_links if link != []])

    i += 1

    for link in okm_linkss:
#       print({'type': '0km','link_web': link})
      model_dict = {
          'type': '0km',
          'link_web': link
      }
      okm_model_links.append(model_dict)
# Out:
# https://www.carone.com.ar/categoria-producto/0km/page/1/
# https://www.carone.com.ar/categoria-producto/0km/page/2/
# https://www.carone.com.ar/categoria-producto/0km/page/3/
# https://www.carone.com.ar/categoria-producto/0km/page/4/
# https://www.carone.com.ar/categoria-producto/0km/page/5/
# https://www.carone.com.ar/categoria-producto/0km/page/6/
# https://www.carone.com.ar/categoria-producto/0km/page/7/
# https://www.carone.com.ar/categoria-producto/0km/page/8/
# https://www.carone.com.ar/categoria-producto/0km/page/9/
# https://www.carone.com.ar/categoria-producto/0km/page/10/
# https://www.carone.com.ar/categoria-producto/0km/page/11/
# https://www.carone.com.ar/categoria-producto/0km/page/12/
# https://www.carone.com.ar/categoria-producto/0km/page/13/
# https://www.carone.com.ar/categoria-producto/0km/page/14/
# https://www.carone.com.ar/categoria-producto/0km/page/15/
# https://www.carone.com.ar/categoria-producto/0km/page/16/
# https://www.carone.com.ar/categoria-producto/0km/page/17/
# https://www.carone.com.ar/categoria-producto/0km/page/18/
# https://www.carone.com.ar/categoria-producto/0km/page/19/
# https://www.carone.com.ar/categoria-producto/0km/page/20/
# https://www.carone.com.ar/categoria-producto/0km/page/21/
# https://www.carone.com.ar/categoria-producto/0km/page/22/
# https://www.carone.com.ar/categoria-producto/0km/page/23/
# https://www.carone.com.ar/categoria-producto/0km/page/24/
# https://www.carone.com.ar/categoria-producto/0km/page/25/
# https://www.carone.com.ar/categoria-producto/0km/page/26/

# %% [markdown]
# ### obtenemos los links para cada modelo 0km y los almacenamos en un dataframe

# %%
df_okm_model_links = pd.DataFrame(okm_model_links)
df_okm_model_links
# Out:
#     type                                           link_web
# 0    0km  https://www.carone.com.ar/producto/tiguan-life...
# 1    0km  https://www.carone.com.ar/producto/alaskan-0km...
# 2    0km  https://www.carone.com.ar/producto/alaskan-con...
# 3    0km  https://www.carone.com.ar/producto/alaskan-con...
# 4    0km  https://www.carone.com.ar/producto/alaskan-0km...
# ..   ...                                                ...
# 292  0km  https://www.carone.com.ar/producto/cronos-driv...
# 293  0km  https://www.carone.com.ar/producto/pulse-drive...
# 294  0km  https://www.carone.com.ar/producto/pulse-drive...
# 295  0km  https://www.carone.com.ar/producto/cronos-driv...
# 296  0km  https://www.carone.com.ar/producto/pulse-impet...
#
# [297 rows x 2 columns]

# %% [markdown]
# ### usando https://www.carone.com.ar/categoria-producto/usados/ para obtener la lista de autos usados

# %%
used_model_links = []

i = 0
while True:
    res = requests.get(f"{base_url}/categoria-producto/usados/page/{i+1}/")
    print(f"{base_url}/categoria-producto/usados/page/{i+1}/")
    if res.status_code != 200:
        break

    soup = BeautifulSoup(res.text, "html.parser")
    tree = html.fromstring(res.content)
    div_col_12_elements = tree.xpath('//div[contains(@class, "col-12")]')
    used_page_links = [div.xpath('.//a/@href') for div in div_col_12_elements]
    used_linkss = set([link[0] for link in used_page_links if link != []])

    i += 1

    for link in used_linkss:
#       print({'type': 'usados','link_web': link})
      model_dict = {
          'type': 'usados',
          'link_web': link
      }
      used_model_links.append(model_dict)
# Out:
# https://www.carone.com.ar/categoria-producto/usados/page/1/
# https://www.carone.com.ar/categoria-producto/usados/page/2/
# https://www.carone.com.ar/categoria-producto/usados/page/3/
# https://www.carone.com.ar/categoria-producto/usados/page/4/
# https://www.carone.com.ar/categoria-producto/usados/page/5/
# https://www.carone.com.ar/categoria-producto/usados/page/6/
# https://www.carone.com.ar/categoria-producto/usados/page/7/
# https://www.carone.com.ar/categoria-producto/usados/page/8/
# https://www.carone.com.ar/categoria-producto/usados/page/9/
# https://www.carone.com.ar/categoria-producto/usados/page/10/
# https://www.carone.com.ar/categoria-producto/usados/page/11/
# https://www.carone.com.ar/categoria-producto/usados/page/12/
# https://www.carone.com.ar/categoria-producto/usados/page/13/
# https://www.carone.com.ar/categoria-producto/usados/page/14/
# https://www.carone.com.ar/categoria-producto/usados/page/15/
# https://www.carone.com.ar/categoria-producto/usados/page/16/
# https://www.carone.com.ar/categoria-producto/usados/page/17/
# https://www.carone.com.ar/categoria-producto/usados/page/18/
# https://www.carone.com.ar/categoria-producto/usados/page/19/
# https://www.carone.com.ar/categoria-producto/usados/page/20/
# https://www.carone.com.ar/categoria-producto/usados/page/21/

# %% [markdown]
# ### obtenemos los links para cada modelo usado y los almacenamos en un dataframe

# %%
df_used_model_links = pd.DataFrame(used_model_links)
df_used_model_links
# Out:
#        type                                           link_web
# 0    usados  https://www.carone.com.ar/producto/chevrolet-p...
# 1    usados  https://www.carone.com.ar/producto/chevrolet-o...
# 2    usados  https://www.carone.com.ar/producto/volkswagen-...
# 3    usados  https://www.carone.com.ar/producto/volkswagen-...
# 4    usados  https://www.carone.com.ar/producto/renault-cli...
# ..      ...                                                ...
# 235  usados  https://www.carone.com.ar/producto/peugeot-300...
# 236  usados  https://www.carone.com.ar/producto/chrysler-je...
# 237  usados  https://www.carone.com.ar/producto/toyota-coro...
# 238  usados  https://www.carone.com.ar/producto/chrysler-je...
# 239  usados  https://www.carone.com.ar/producto/volkswagen-...
#
# [240 rows x 2 columns]

# %%
df_model_links = pd.concat([df_okm_model_links, df_used_model_links], ignore_index=True)
df_model_links
# Out:
#        type                                           link_web
# 0       0km  https://www.carone.com.ar/producto/tiguan-life...
# 1       0km  https://www.carone.com.ar/producto/alaskan-0km...
# 2       0km  https://www.carone.com.ar/producto/alaskan-con...
# 3       0km  https://www.carone.com.ar/producto/alaskan-con...
# 4       0km  https://www.carone.com.ar/producto/alaskan-0km...
# ..      ...                                                ...
# 532  usados  https://www.carone.com.ar/producto/peugeot-300...
# 533  usados  https://www.carone.com.ar/producto/chrysler-je...
# 534  usados  https://www.carone.com.ar/producto/toyota-coro...
# 535  usados  https://www.carone.com.ar/producto/chrysler-je...
# 536  usados  https://www.carone.com.ar/producto/volkswagen-...
#
# [537 rows x 2 columns]

# %%
df_model_links.to_csv('../CSV/df_carone_model_links.csv', index=False)

# %%
df_all_model_links = pd.read_csv('../CSV/df_carone_model_links.csv')
df_all_model_links
# Out:
#        type                                           link_web
# 0       0km  https://www.carone.com.ar/producto/tiguan-life...
# 1       0km  https://www.carone.com.ar/producto/alaskan-0km...
# 2       0km  https://www.carone.com.ar/producto/alaskan-con...
# 3       0km  https://www.carone.com.ar/producto/alaskan-con...
# 4       0km  https://www.carone.com.ar/producto/alaskan-0km...
# ..      ...                                                ...
# 532  usados  https://www.carone.com.ar/producto/peugeot-300...
# 533  usados  https://www.carone.com.ar/producto/chrysler-je...
# 534  usados  https://www.carone.com.ar/producto/toyota-coro...
# 535  usados  https://www.carone.com.ar/producto/chrysler-je...
# 536  usados  https://www.carone.com.ar/producto/volkswagen-...
#
# [537 rows x 2 columns]

# %%
df_okm_links = df_all_model_links[df_all_model_links['type'] == '0km']
df_okm_links
# Out:
#     type                                           link_web
# 0    0km  https://www.carone.com.ar/producto/tiguan-life...
# 1    0km  https://www.carone.com.ar/producto/alaskan-0km...
# 2    0km  https://www.carone.com.ar/producto/alaskan-con...
# 3    0km  https://www.carone.com.ar/producto/alaskan-con...
# 4    0km  https://www.carone.com.ar/producto/alaskan-0km...
# ..   ...                                                ...
# 292  0km  https://www.carone.com.ar/producto/cronos-driv...
# 293  0km  https://www.carone.com.ar/producto/pulse-drive...
# 294  0km  https://www.carone.com.ar/producto/pulse-drive...
# 295  0km  https://www.carone.com.ar/producto/cronos-driv...
# 296  0km  https://www.carone.com.ar/producto/pulse-impet...
#
# [297 rows x 2 columns]

# %%
okm_models_description = []
# okm_links = [url['link_web'] for url in okm_model_links if url['type'] == '0km']

for link in list(df_okm_links['link_web']):
  res = requests.get(link)
  soup = BeautifulSoup(res.text, "html.parser")
  tree = html.fromstring(res.content)
  model_name = tree.xpath('/html/body/div[1]/div[4]/div/div/div/div/div[1]/div/div/div/div/div[2]/h1/text()')
  # print(model_name[0].replace("\n"))
  model_version = tree.xpath('/html/body/div[1]/div[4]/div/div/div/div/div[1]/div/div/div/div/div[2]/span/text()')
  # print(model_version)
  model_price = tree.xpath('/html/body/div[1]/div[4]/div/div/div/div/div[1]/div/div/div/div/div[2]/p[2]/span/bdi/text()')
  model_caja = tree.xpath('/html/body/div[1]/div[4]/div/div/div/div/div[1]/div/div/div/section[2]/div[4]/div/div/div/div[2]/ul/li[8]/text()')
  model_puertas_count = tree.xpath('/html/body/div[1]/div[4]/div/div/div/div/div[1]/div/div/div/section[2]/div[4]/div/div/div/div[2]/ul[4]/li[4]/text()')
  model_potencia = tree.xpath('/html/body/div[1]/div[4]/div/div/div/div/div[1]/div/div/div/section[2]/div[4]/div/div/div/div[2]/ul[1]/li[3]/text()')

  if model_price == [] or model_caja == [] or model_puertas_count == [] or model_potencia == []:
    print({'model_name': model_name[0].replace("\n", ""), 'model_version': model_version[0].replace("\n", ""), 'model_price': model_price, 'model_caja': model_caja, 'model_puertas_count': model_puertas_count, 'model_potencia': model_potencia})
    okm_models_description.append({'Model': model_name[0].replace("\n", ""), 'Version': model_version[0].replace("\n", ""), 'Price': "Nan", 'Caja': "Nan", 'Cant. puertas': "Nan", 'Potencia': "Nan"})
  elif model_price != [] or model_caja != [] or model_puertas_count != [] or model_potencia != []:
    print({'model_name': model_name[0].replace("\n", ""), 'model_version': model_version[0].replace("\n", ""), 'model_price': model_price, 'model_caja': model_caja, 'model_puertas_count': model_puertas_count, 'model_potencia': model_potencia})
    okm_models_description.append({'Model': model_name[0].replace("\n", ""), 'Version': model_version[0].replace("\n", ""), 'Price': model_price[0], 'Caja': model_caja[0], 'Cant. puertas': model_puertas_count[0].replace("Puertas: ", ""), 'Potencia': model_potencia[0].replace("Potencia: ", "")})
# Out:
# {'model_name': 'Volkswagen Tiguan Allspace', 'model_version': 'Life 350TSI', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'Emotion Mt 4x2', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'Confort Mt 4x2', 'model_price': ['11.050.000'], 'model_caja': ['Capacidad de carga: 1tn', 'Sistema de anclajes ISOFIX ®', 'Neumáticos 255/70 R16 (símil rueda de auxilio)', 'Velocidades: 6'], 'model_puertas_count': ['Puertas: 4'], 'model_potencia': ['Potencia: 160 CV']}
# {'model_name': 'Renault Alaskan', 'model_version': 'CONFORT 60 2WD ', 'model_price': ['11.350.000'], 'model_caja': ['Capacidad de carga: 1tn', 'Sistema de anclajes ISOFIX ®', 'Neumáticos 255/70 R16 (símil rueda de auxilio)', 'Velocidades: 6'], 'model_puertas_count': ['Puertas: 4'], 'model_potencia': ['Potencia: 160 CV']}
# {'model_name': 'Renault Alaskan', 'model_version': 'Confort Mt 4x4', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'CONFORT 60 2WD ', 'model_price': ['11.350.000'], 'model_caja': ['Capacidad de carga: 1tn', 'Sistema de anclajes ISOFIX ®', 'Neumáticos 255/70 R16 (símil rueda de auxilio)', 'Velocidades: 6'], 'model_puertas_count': ['Puertas: 4'], 'model_potencia': ['Potencia: 160 CV']}
# {'model_name': 'Renault Alaskan', 'model_version': 'CONFORT 60 2WD ', 'model_price': ['11.350.000'], 'model_caja': ['Capacidad de carga: 1tn', 'Sistema de anclajes ISOFIX ®', 'Neumáticos 255/70 R16 (símil rueda de auxilio)', 'Velocidades: 6'], 'model_puertas_count': ['Puertas: 4'], 'model_potencia': ['Potencia: 160 CV']}
# {'model_name': 'Renault Alaskan', 'model_version': 'Confort Mt 4x2', 'model_price': ['11.050.000'], 'model_caja': ['Capacidad de carga: 1tn', 'Sistema de anclajes ISOFIX ®', 'Neumáticos 255/70 R16 (símil rueda de auxilio)', 'Velocidades: 6'], 'model_puertas_count': ['Puertas: 4'], 'model_potencia': ['Potencia: 160 CV']}
# {'model_name': 'Renault Alaskan', 'model_version': 'EMOTION 190 4WD', 'model_price': ['14.250.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'EMOTION 190 2WD', 'model_price': ['12.750.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'CONFORT 160 4WD', 'model_price': ['12.800.000'], 'model_caja': ['Capacidad de carga: 1tn', 'Sistema de anclajes ISOFIX ®', 'Neumáticos 255/70 R16 (símil rueda de auxilio)', 'Velocidades: 6'], 'model_puertas_count': ['Puertas: 4'], 'model_potencia': ['Potencia: 160 CV']}
# {'model_name': 'Renault Alaskan', 'model_version': 'Confort Mt 4x2', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'Emotion Mt 4x4', 'model_price': ['13.650.000'], 'model_caja': ['Capacidad de arrastre: 3,5 tns', 'Asistencia al frenado de urgencia (AFU)'], 'model_puertas_count': [], 'model_potencia': ['Transmisión: manual de 6 velocidades']}
# {'model_name': 'Renault Alaskan', 'model_version': 'INTENS 190 2WD AT', 'model_price': ['14.350.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'Iconic 4x4 Mt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'INTENS 190 4WD AT', 'model_price': ['16.050.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'INTENS 190 2WD', 'model_price': ['13.750.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'Iconic At 4x4', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'ICONIC 190 4WD AT', 'model_price': ['16.750.000'], 'model_caja': ['Capacidad de arrastre: 3,5 tns', 'Cámara de visión 360° (Multiview camera) con detector de objetos en movimiento y modo Offroad'], 'model_puertas_count': [], 'model_potencia': ['Transmisión: manual de 6 velocidades']}
# {'model_name': 'Renault Alaskan', 'model_version': 'Emotion Mt 4x4', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'Intens Mt 4x2', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'Emotion Mt 4x4', 'model_price': ['13.900.000'], 'model_caja': ['Capacidad de arrastre: 3,5 tns', 'Asistencia al frenado de urgencia (AFU)'], 'model_puertas_count': [], 'model_potencia': ['Transmisión: manual de 6 velocidades']}
# {'model_name': 'Renault Alaskan', 'model_version': 'ICONIC 190 4WD AT', 'model_price': ['16.750.000'], 'model_caja': ['Capacidad de arrastre: 3,5 tns', 'Cámara de visión 360° (Multiview camera) con detector de objetos en movimiento y modo Offroad'], 'model_puertas_count': [], 'model_potencia': ['Transmisión: manual de 6 velocidades']}
# {'model_name': 'Renault Alaskan', 'model_version': 'INTENS 190 4WD', 'model_price': ['15.450.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'NUEVA SERIE LIMITADA Outsider ', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Active 1.6L', 'model_price': ['7.816.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Active 1.6L AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 2008', 'model_version': 'Feline 1.6 Tiptronic', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 2008', 'model_version': 'Sport 1.6 Thp Tiptronic', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Active 1.6L', 'model_price': ['7.816.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Active 1.6L AM23', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'Intens Mt 4x4', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 2008', 'model_version': 'Feline 1.6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Alaskan', 'model_version': 'OUTSIDER 190 4WD AT', 'model_price': ['16.750.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 3008', 'model_version': 'Gt Pack HYBRID4 AM22', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 3008', 'model_version': 'GT Pack AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Active Pack 1.6L Tiptronic AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Active Pack 1.6L Tiptronic', 'model_price': ['8.263.020'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Active Pack 1.6L AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Style Tiptronic 1.6L', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Allure Pack 1.6L Tiptronic AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Active Pack 1.6L Tiptronic', 'model_price': ['8.263.020'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Active Tiptronic 1.6L AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Allure 1.6L AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Allure Pack 1.6L AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Allure 1.6L AM23', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Style 1.6L', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Active Tiptronic 1.6L AM23', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 3008', 'model_version': 'GT Pack THP Tiptronic AM23', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Feline 1.6L Tiptronic AM23', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Allure Tiptronic 1.6L AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Allure Pack 1.6L ', 'model_price': ['8.101.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Peugeot 3008', 'model_version': 'Allure Pack AM23', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Feline 1.6L Tiptronic AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 5008', 'model_version': 'GT Pack AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Allure Pack 1.6L ', 'model_price': ['8.101.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Peugeot 208', 'model_version': 'New Like 1.2L AM23.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Allure Tiptronic 1.6L AM23', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot 208', 'model_version': 'Allure Pack 1.6L ', 'model_price': ['8.101.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Peugeot 208', 'model_version': 'Feline Tiptronic 1.6L', 'model_price': ['10.207.260'], 'model_caja': ['Caja: Automático'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'V6 Extreme 4x4 Aut 258Cv', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'CD 2.0 Tdi Trendline 4x4', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'CD 2.0 Tdi Trendline 4x2', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'Comfortline V6 3.0 Tdi 4x4 Aut 258Cv', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'CD 2.0 Tdi Highline 4x2 Aut', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'CD 2.0 Tdi Highline 4x2', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'CD 2.0 Tdi Comfortline 4x4', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'CD 2.0 Tdi Highline 4x4', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'CD 2.0 Tdi Highline 4x4 Aut', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'CD 2.0 Tdi Comfortline 4x2 Aut', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'CD 2.0 Tdi Comfortline 4x2', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'V6 Black Style 4x4 Aut 258Cv', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Haval H1', 'model_version': 'Elite My2019', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Haval H1', 'model_version': 'Comfort My2019', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Amarok', 'model_version': 'V6 Highline 4x4 Aut 258Cv', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Mitsubishi L200', 'model_version': '2.4L Gls 6At Full', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Changan MD', 'model_version': '201 Cargo Box', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Changan M', 'model_version': '201 Cargo Van', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Changan CS15', 'model_version': 'Luxury Dct', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Changan CS15', 'model_version': 'Comfort Dct', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Changan CS15', 'model_version': 'Comfort Mt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Haval H2', 'model_version': 'Comfort Mt My2019', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Mitsubishi L200', 'model_version': '2.4L Gls 6Mt Full', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Haval H1', 'model_version': 'Luxury My2019', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Boxer', 'model_version': 'Boxer Premium 2.2 HDI 435 M', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Great Wall Wingle 6', 'model_version': 'Dignity 4x4 My2019', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Boxer', 'model_version': 'Boxer Premium 2.2HDI 440 L4H2 130 MINI-BUS 17+1', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Boxer', 'model_version': 'Premium 2.2HDI 440 L4H2 130 MINI-BUS 17+1', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Boxer', 'model_version': 'Boxer Premium 2.2 HDI 435MH 130', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Changan MD', 'model_version': '201 Pick Up', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Boxer', 'model_version': 'Boxer Premium 2.2 HDI 435LH 130', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Great Wall Wingle 5', 'model_version': 'Cabina Doble Standard 4x4 My2019', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Great Wall Wingle 5', 'model_version': 'Cabina Simple Standard 4x2 My2019', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Great Wall Wingle 5', 'model_version': 'Cabina Doble Standard 4x2 My2019', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Great Wall Wingle 5', 'model_version': 'Cabina Doble Luxury 4x2 My2019', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Boxer', 'model_version': 'Boxer Premium 2.2 HDI 440 L3 CHASIS 130', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Cruze', 'model_version': '5P 1.4 Turbo Lt Mt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Cruze', 'model_version': '5P 1.4 Turbo Premier Ii At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Cruze', 'model_version': '4P 1.4 Turbo Lt AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Cruze', 'model_version': 'CRUZE 4P 1.4T MIDNIGHT AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Cruze', 'model_version': '5P 1.4 Turbo Lt AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Boxer', 'model_version': 'Premium 2.2 HDI 440 L3 CH 130 CHASIS CABINA', 'model_price': ['15.401.400'], 'model_caja': ['Inmovilizador de motor', 'Computadora de abordo'], 'model_puertas_count': [], 'model_potencia': ['Ayuda al Arranque en Pendiente (HILL ASSIST)']}
# {'model_name': 'Chevrolet Cruze', 'model_version': '4P 1.4 Turbo Premier Ii At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Cruze', 'model_version': '4P 1.4 Turbo Ltz+ At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Cruze', 'model_version': '5P 1.4 Turbo RS AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Cruze', 'model_version': '4P 1.4 Turbo Lt Mt S/Onstar', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Boxer', 'model_version': 'Premium 2.2 HDI 440 L3 CH 130 CHASIS CABINA', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Cruze', 'model_version': '5P 1.4 Turbo Lt Mt S/Onstar', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'Emotion 1.6 SCe 114 2WD', 'model_price': ['10.050.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'Iconic 1.3 TCe 163 CVT 2WD', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'ICONIC 1.3 TCe 163 2WD CVT', 'model_price': ['10.950.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'Emotion 1.6 SCe 114 2WD', 'model_price': ['10.350.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Nuevo Duster', 'model_version': 'Iconic 1.3T Cvt 4x2', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'Outsider 1.3 TCe 163 4WD', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'ICONIC 1.3 TCe 163 2WD CVT', 'model_price': ['10.950.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'Emotion 1.6 SCe 114 2WD', 'model_price': ['10.050.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'ICONIC 1.3 TCe 163 2WD CVT', 'model_price': ['10.950.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'Emotion 1.6 SCe 114 2WD', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'ICONIC 1.3 TCe 163 2WD CVT', 'model_price': ['10.750.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Oroch', 'model_version': 'ICONIC 1.3 TCe 163 2WD CVT', 'model_price': ['10.950.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Nuevo Duster', 'model_version': 'Iconic 1.3T Mt 4x4', 'model_price': ['15.150.000'], 'model_caja': ['Llantas 17″ Aluminio / Diamantadas'], 'model_puertas_count': [], 'model_potencia': ['Potencia máxima: 155 cv']}
# {'model_name': 'Chevrolet Equinox', 'model_version': '1.5T RS FWD AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Nuevo Duster', 'model_version': 'Intens 1.6 Cvt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Joy', 'model_version': '1.4 N MT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Expert', 'model_version': 'Premium 1.6 Hdi', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Equinox', 'model_version': '1.5T PREMIER AWD AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Nuevo Duster', 'model_version': 'Outsider 1.3T Cvt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Expert', 'model_version': 'Premium 1.6 Hdi 6 Pasajeros', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Nuevo Duster', 'model_version': 'Intens 1.6 Mt ', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Nuevo Duster', 'model_version': 'Zen 1.6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Fiorino', 'model_version': 'Furgón Pack Top', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Nuevo Duster', 'model_version': 'Iconic 1.3T Mt 4x4', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Kangoo', 'model_version': 'Zen', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Kangoo', 'model_version': 'Stepway 1.6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet JOY Plus 1.4 N MT', 'model_version': '1.4', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Kangoo Express', 'model_version': 'Confort 1.5 Dci', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Kangoo Express', 'model_version': 'Confort 5 Asientos 1.6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Kangoo II', 'model_version': 'Stepway 1.5 Dci', 'model_price': ['9.500.000'], 'model_caja': ['Cierre centralizado de puertas con cierre automático en rodaje'], 'model_puertas_count': [], 'model_potencia': ['Potencia máxima:89 CV']}
# {'model_name': 'Renault Kangoo', 'model_version': 'Life', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Joy', 'model_version': '1.4 N MT BLACK', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Joy Plus', 'model_version': '1.4 N MT BLACK', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Kangoo Express', 'model_version': 'Confort 1.6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Kangoo', 'model_version': 'Stepway 1.5 Dci', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Kangoo Express', 'model_version': 'Confort 5 Asientos 1.5 Dci', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Kangoo II', 'model_version': 'EMOTION 5A 1.6 SCe', 'model_price': ['9.130.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Kangoo II', 'model_version': 'EXPRESS CONFORT 5A 1.6 SCe', 'model_price': ['8.530.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Kangoo II', 'model_version': 'EXPRESS CONFORT 5A 1.6 SCe', 'model_price': ['8.530.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Kangoo II', 'model_version': 'EXPRESS CONFORT 1.5 dCI', 'model_price': ['8.230.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Kangoo II ', 'model_version': 'EXPRESS CONFORT 5A 1.5 dCi', 'model_price': ['9.130.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Kangoo II', 'model_version': 'EXPRESS CONFORT 1.5 dCI', 'model_price': ['8.230.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Kangoo Express', 'model_version': 'Emotion 1.6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Kangoo II', 'model_version': 'EMOTION 5A 1.6 SCe', 'model_price': ['9.130.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Kangoo II', 'model_version': 'EXPRESS CONFORT 5A 1.6 SCe', 'model_price': ['8.530.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Kangoo II', 'model_version': 'EMOTION 1.6 SCe', 'model_price': ['8.330.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Kangoo II', 'model_version': 'EXPRESS CONFORT 1.6 SCe', 'model_price': ['7.630.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Kangoo II', 'model_version': 'EXPRESS CONFORT 1.6 SCe', 'model_price': ['7.630.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Logan', 'model_version': 'LIFE 1.6', 'model_price': ['5.900.000'], 'model_caja': ['Llantas de acero de 15´´ / Neumáticos 185 / 65 R 15'], 'model_puertas_count': [], 'model_potencia': ['Potencia máxima: 115 cv']}
# {'model_name': 'Renault Koleos', 'model_version': 'Intens 2.5 4Wd Cvt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Montana', 'model_version': '1.2T LTZ AT', 'model_price': ['11.590.900'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 8']}
# {'model_name': 'Renault Logan', 'model_version': 'LIFE 1.6', 'model_price': ['5.900.000'], 'model_caja': ['Llantas de acero de 15´´ / Neumáticos 185 / 65 R 15'], 'model_puertas_count': [], 'model_potencia': ['Potencia máxima: 115 cv']}
# {'model_name': 'Renault Logan', 'model_version': 'Zen', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Logan', 'model_version': 'LIFE 1.6', 'model_price': ['5.900.000'], 'model_caja': ['Llantas de acero de 15´´ / Neumáticos 185 / 65 R 15'], 'model_puertas_count': [], 'model_potencia': ['Potencia máxima: 115 cv']}
# {'model_name': 'Renault Logan', 'model_version': 'INTENS 1.6', 'model_price': ['6.650.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 8']}
# {'model_name': 'Renault Kangoo Express', 'model_version': 'Emotion 5 Asientos 1.6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Logan', 'model_version': 'LIFE 1.6', 'model_price': ['5.900.000'], 'model_caja': ['Llantas de acero de 15´´ / Neumáticos 185 / 65 R 15'], 'model_puertas_count': [], 'model_potencia': ['Potencia máxima: 115 cv']}
# {'model_name': 'Renault Logan', 'model_version': 'Life', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Mobi', 'model_version': 'Like', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Logan', 'model_version': 'Intens', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix', 'model_version': '1.2 Lt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Nivus', 'model_version': 'Hero 200 Tsi At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Montana', 'model_version': '1.2T PREMIER AT', 'model_price': ['12.449.900'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 8']}
# {'model_name': 'Chevrolet Onix', 'model_version': '1.2', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Nivus', 'model_version': 'Highline 200 Tsi At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Montana', 'model_version': '1.2T PREMIER AT', 'model_price': ['12.449.900'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 8']}
# {'model_name': 'Chevrolet Montana', 'model_version': '1.2T PREMIER AT', 'model_price': ['12.449.900'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 8']}
# {'model_name': 'Chevrolet Onix', 'model_version': '1.2 Lt Tech C/Onstar', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Montana', 'model_version': '1.2T PREMIER AT', 'model_price': ['12.449.900'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 8']}
# {'model_name': 'Chevrolet Onix', 'model_version': '1.2 Lt Tech', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Montana', 'model_version': '1.2T PREMIER AT', 'model_price': ['12.449.900'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 8']}
# {'model_name': 'Volkswagen Nivus', 'model_version': 'Comfortline 200 Tsi At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix', 'model_version': 'Ltz 1.0 T At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix Plus', 'model_version': ' 1.0T Premier I Mt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix Plus', 'model_version': '1.2', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix Plus', 'model_version': '1.2 Lt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix', 'model_version': '1.0T Premier I Mt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix Plus', 'model_version': '1.0T Premier Ii At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix Plus', 'model_version': '1.2 Lt Tech C/Onstar', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix Plus', 'model_version': 'Ltz 1.0 T At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix', 'model_version': '1.0T Premier Ii At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix', 'model_version': '1Rs 1.0 T', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix Plus', 'model_version': '1.2 Lt Tech', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Onix', 'model_version': 'Ltz 1.0 T Mt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Polo', 'model_version': 'Highline 1.6 At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Partner', 'model_version': 'Confort 1.6 115', 'model_price': ['7.544.300'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 8']}
# {'model_name': 'Peugeot Partner', 'model_version': 'Confort 1.6 Hdi', 'model_price': ['8.020.400'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 8']}
# {'model_name': 'Peugeot Partner', 'model_version': 'Confort 1.6 HDI 92 AM22.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Partner', 'model_version': 'Patagonica VTC Plus 1.6 HDI 92 AM22.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Polo', 'model_version': 'Trendline 1.6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Polo', 'model_version': 'Gts 1.4 At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Polo', 'model_version': 'Trendline At 1.6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Partner', 'model_version': 'Patagonica VTC Plus 1.6 115 AM22.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Partner', 'model_version': 'Confort 1.6 115 AM22.5', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Peugeot Partner', 'model_version': 'Patagonica VTC Plus 1.6 115 ', 'model_price': ['9.559.180'], 'model_caja': ['Alarma de faros encendidos', 'Recomendador de cambio de marcha (GSI)'], 'model_puertas_count': [], 'model_potencia': ['Airbags frontales conductor y pasajero']}
# {'model_name': 'Chevrolet Onix Plus', 'model_version': 'Ltz 1.0 T Mt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 2.8 TD 4X2 LT MT', 'model_price': ['12.710.304'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 2.8 TD 4X2 LT MT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': '2.8 TD 4X4 LT AT', 'model_price': ['14.548.827'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 2.8 TD 4X4 LTZ AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 4x2 Lt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': 'CD 2.8 TD 4X4 Z71 AT ', 'model_price': ['14.958.027'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 4x2 Ls', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 2.8 TD 4X2 LTZ MT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 2.8 4x4 Z71 AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 2.8 TD 4X4 LT MT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': 'CD 2.8 TD 4X4 LTZ AT', 'model_price': ['16.137.793'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Chevrolet S10', 'model_version': 'CD 2.8 TD 4X4 HC AT ', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'Intens Cvt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 4x4 Lt At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'Gt Line', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 4x4 High Country At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'Gt Line Cvt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'LIFE 1.6', 'model_price': ['5.530.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Sandero', 'model_version': 'INTENS 1.6', 'model_price': ['6.590.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Chevrolet S10', 'model_version': 'Cabina Doble 4x4 Lt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'Life', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'Intens', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet S10', 'model_version': 'CD 2.8 TD 4X4 LT AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'INTENS 1.6', 'model_price': ['6.590.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Volkswagen Saveiro', 'model_version': 'Cabina Doble Cross', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'ZEN 1.6', 'model_price': ['6.050.000'], 'model_caja': ['Llantas de acero de 15´´ / Neumáticos 185 / 65 R 15'], 'model_puertas_count': [], 'model_potencia': ['Potencia máxima: 115 cv']}
# {'model_name': 'Renault Sandero', 'model_version': 'ZEN 1.6', 'model_price': ['6.050.000'], 'model_caja': ['Llantas de acero de 15´´ / Neumáticos 185 / 65 R 15'], 'model_puertas_count': [], 'model_potencia': ['Potencia máxima: 115 cv']}
# {'model_name': 'Volkswagen Saveiro', 'model_version': 'Cabina Doble Highline', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'LIFE 1.6', 'model_price': ['5.530.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Sandero', 'model_version': 'ZEN 1.6', 'model_price': ['6.050.000'], 'model_caja': ['Llantas de acero de 15´´ / Neumáticos 185 / 65 R 15'], 'model_puertas_count': [], 'model_potencia': ['Potencia máxima: 115 cv']}
# {'model_name': 'Volkswagen Saveiro', 'model_version': 'Cabina Doble Comfortline', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Saveiro', 'model_version': 'Cabina Simple - Trendline', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'Rs', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'ZEN 1.6', 'model_price': ['6.050.000'], 'model_caja': ['Llantas de acero de 15´´ / Neumáticos 185 / 65 R 15'], 'model_puertas_count': [], 'model_potencia': ['Potencia máxima: 115 cv']}
# {'model_name': 'Renault Sandero', 'model_version': 'Zen', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Sandero', 'model_version': 'LIFE 1.6', 'model_price': ['5.530.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Stepway', 'model_version': 'INTENS 1.6', 'model_price': ['7.210.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Stepway', 'model_version': 'ZEN 1.6', 'model_price': ['6.650.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Stepway', 'model_version': 'ZEN 1.6', 'model_price': ['6.650.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Stepway', 'model_version': 'INTENS 1.6', 'model_price': ['7.210.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Stepway', 'model_version': 'INTENS 1.6', 'model_price': ['7.210.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Stepway', 'model_version': 'ZEN 1.6', 'model_price': ['6.650.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Stepway', 'model_version': 'Zen', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Strada', 'model_version': 'Endurance 1.4 Cabina Doble', 'model_price': ['8.420.000'], 'model_caja': ['Cinturones de seguridad con pretensores'], 'model_puertas_count': ['Volante regulable en altura'], 'model_potencia': ['Iluminación en caja de carga']}
# {'model_name': 'Fiat Strada', 'model_version': 'Endurance 1.4 Cabina Doble', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Stepway', 'model_version': 'Intens Cvt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Renault Stepway', 'model_version': 'INTENS 1.6', 'model_price': ['7.210.000'], 'model_caja': ['Caja: Manual'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Renault Stepway', 'model_version': 'Intens', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Strada', 'model_version': 'Volcano 1.3 Cabina Doble', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Strada', 'model_version': 'Endurance 1.4 Cabina Simple', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Strada', 'model_version': 'FREDDOM 1.4 Cabina Doble', 'model_price': ['8.980.000'], 'model_caja': ['Caja de cambios: Manual de 5 vel.', 'Capota cubre carga'], 'model_puertas_count': [], 'model_potencia': ['N° de válvulas por cilindro: 2']}
# {'model_name': 'Volkswagen T-Cross', 'model_version': 'Trendline Mt', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Strada', 'model_version': 'FREDDOM 1.4 Cabina Doble', 'model_price': ['8.980.000'], 'model_caja': ['Caja de cambios: Manual de 5 vel.', 'Capota cubre carga'], 'model_puertas_count': [], 'model_potencia': ['N° de válvulas por cilindro: 2']}
# {'model_name': 'Fiat Strada', 'model_version': 'FREDDOM TECH 1.4 8v MT CD', 'model_price': ['9.630.000'], 'model_caja': ['Caja de cambios: Manual de 5 vel.', 'Capota cubre carga'], 'model_puertas_count': [], 'model_potencia': ['N° de válvulas por cilindro: 2']}
# {'model_name': 'Fiat Strada', 'model_version': 'Volcano 1.3 Cabina Doble', 'model_price': ['10.270.000'], 'model_caja': ['Caja de cambios: Manual de 5 vel.', 'Capota cubre carga'], 'model_puertas_count': [], 'model_potencia': ['N° de válvulas por cilindro: 2']}
# {'model_name': 'Volkswagen T-Cross', 'model_version': 'Highline At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Strada', 'model_version': 'RANCH 1.3 CVT Cabina Doble', 'model_price': ['10.960.000'], 'model_caja': ['Caja de cambios: Manual de 5 vel.', 'Capota cubre carga'], 'model_puertas_count': [], 'model_potencia': ['N° de válvulas por cilindro: 2']}
# {'model_name': 'Fiat Strada', 'model_version': 'Freedom 1.4 Cabina Doble', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Strada', 'model_version': 'FREDDOM 1.4 Cabina Doble', 'model_price': ['8.980.000'], 'model_caja': ['Caja de cambios: Manual de 5 vel.', 'Capota cubre carga'], 'model_puertas_count': [], 'model_potencia': ['N° de válvulas por cilindro: 2']}
# {'model_name': 'Volkswagen T-Cross', 'model_version': 'Comfortline At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Taos', 'model_version': 'Highline 250 Tsi', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Taos', 'model_version': 'Comfortline 250 Tsi', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Toro', 'model_version': 'FREEDOM 2.0 16v CD 4x4 AT9 (PACK)', 'model_price': ['15.770.000'], 'model_caja': ['Caja: Automático'], 'model_puertas_count': [], 'model_potencia': ['Valculas: 16']}
# {'model_name': 'Fiat Toro', 'model_version': 'Volcano 1,3T 270 16Vcd 4x2 At6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Taos', 'model_version': 'Hero 250 Tsi', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Toro', 'model_version': 'Freedom 2,0 16V Multiet Cd 4x4 At9', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Toro', 'model_version': 'Volcano 2.0 16V Multijet Cd 4x4 At9', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Tracker', 'model_version': '1.2T At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Toro', 'model_version': 'Freedom 1.8 16V Nafta Cd 4x2 At6', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Tracker', 'model_version': '1.2T At Ltz', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Toro', 'model_version': 'Ultra 2.0 16V Multijet Cd 4x4 At9', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Touareg', 'model_version': '3.0 V6 Tdi Premium', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Virtus', 'model_version': 'Trendline Tiptronic', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Virtus', 'model_version': 'Trendline Manual', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Cronos', 'model_version': 'Precision 1.8 16V Pack Style', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Vento', 'model_version': 'Highline 250 Tsi At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Virtus', 'model_version': 'Highline Tiptronic', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Tracker', 'model_version': '1.2T At Premier', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Virtus', 'model_version': 'Comfortline Tiptronic', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Cronos', 'model_version': 'Attractive 1.3', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Cronos', 'model_version': 'Drive 1.3 S-Design', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Chevrolet Trailblazer', 'model_version': '2.8 4X4 LTZ AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Volkswagen Virtus', 'model_version': 'Gts 1.4 At', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Cronos', 'model_version': 'Style 1.3 GSE', 'model_price': ['7.340.000'], 'model_caja': ['Control de Estabilidad'], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Cronos', 'model_version': 'Drive 1.3 Gse Pack Conectividad', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Pulse', 'model_version': 'Impetus', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Cronos', 'model_version': 'DRIVE 1.3 GSE PACK PLUS', 'model_price': ['7.017.000'], 'model_caja': ['Computadora de a bordo'], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Cronos', 'model_version': 'DRIVE 1.3 GSE PACK PLUS', 'model_price': ['7.017.000'], 'model_caja': ['Computadora de a bordo'], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Cronos', 'model_version': 'DRIVE 1.3 GSE PACK PLUS', 'model_price': ['7.017.000'], 'model_caja': ['Computadora de a bordo'], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Pulse', 'model_version': 'Drive MT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Pulse', 'model_version': 'Drive AT', 'model_price': [], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Cronos', 'model_version': 'DRIVE 1.3 GSE PACK PLUS', 'model_price': ['7.017.000'], 'model_caja': ['Computadora de a bordo'], 'model_puertas_count': [], 'model_potencia': []}
# {'model_name': 'Fiat Pulse', 'model_version': 'IMPETUS 1.0 CVT', 'model_price': ['12.960.000'], 'model_caja': [], 'model_puertas_count': [], 'model_potencia': []}

# %%
df_okm_models_description = pd.DataFrame(okm_models_description)
df_okm_models_description['type'] = "0km"
df_okm_models_description
# Out:
#                           Model                  Version       Price  \
# 0    Volkswagen Tiguan Allspace              Life 350TSI         Nan
# 1               Renault Alaskan           Emotion Mt 4x2         Nan
# 2               Renault Alaskan           Confort Mt 4x2  11.050.000
# 3               Renault Alaskan          CONFORT 60 2WD   11.350.000
# 4               Renault Alaskan           Confort Mt 4x4         Nan
# ..                          ...                      ...         ...
# 292                 Fiat Cronos  DRIVE 1.3 GSE PACK PLUS         Nan
# 293                  Fiat Pulse                 Drive MT         Nan
# 294                  Fiat Pulse                 Drive AT         Nan
# 295                 Fiat Cronos  DRIVE 1.3 GSE PACK PLUS         Nan
# 296                  Fiat Pulse          IMPETUS 1.0 CVT         Nan
#
#                         Caja Cant. puertas Potencia type
# 0                        Nan           Nan      Nan  0km
# 1                        Nan           Nan      Nan  0km
# 2    Capacidad de carga: 1tn             4   160 CV  0km
# 3    Capacidad de carga: 1tn             4   160 CV  0km
# 4                        Nan           Nan      Nan  0km
# ..                       ...           ...      ...  ...
# 292                      Nan           Nan      Nan  0km
# 293                      Nan           Nan      Nan  0km
# 294                      Nan           Nan      Nan  0km
# 295                      Nan           Nan      Nan  0km
# 296                      Nan           Nan      Nan  0km
#
# [297 rows x 7 columns]
